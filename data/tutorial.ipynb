# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
price_files = {
    -2: "./capsule/prices_round_0_day_-2.csv",
    -1: "./capsule/prices_round_0_day_-1.csv",
}

trade_files = {
    -2: "./capsule/trades_round_0_day_-2.csv",
    -1: "./capsule/trades_round_0_day_-1.csv",
}

# %%
# TODO
